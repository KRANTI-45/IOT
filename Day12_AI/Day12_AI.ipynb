# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('./Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# find correlation
for column in df.columns:
    corr = np.corrcoef(df['sales'],df[column])
    print(f"Correlation betweem Sales and {column} = {corr[0,1]}")
# Out:
# Correlation betweem Sales and TV = 0.7822244248616061
# Correlation betweem Sales and radio = 0.5762225745710551
# Correlation betweem Sales and newspaper = 0.22829902637616528
# Correlation betweem Sales and sales = 0.9999999999999998

# %%
x = df.drop(['sales'],axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=12345)

# %%
len(x_train)
# Out:
# 160

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
y_predictions = model.predict(x_test)

# %%
print(y_predictions)
# Out:
# [20.58935664 10.09590671 14.42381891  9.79585535  8.73225619 16.20408891
#  20.39278011 12.56235681 22.92765938 21.10131154  9.92179135 17.8979443
#   5.70225474 10.5664707   9.96834767 15.90910547 23.39111934 23.7097652
#   7.24646448 12.12109567 12.39752436 17.5662417   6.3675117  18.07556846
#  19.94096474 10.16209681  6.35217736 15.41389362  5.76401557 13.66514911
#  17.03223375  6.89831468 10.13094691  8.77032794 13.8059915  10.90853057
#  22.63644821  8.95010082 14.2714381  13.65935027]

# %%
plt.scatter(x_test['TV'],y_test)
plt.plot(x_test['TV'],y_predictions,color='red',label="regression line")
plt.legend()
plt.xlabel('TV')
plt.ylabel('sales')
plt.title('TV Vs Sales OBSERVED OUTPUT')
# Out:
# Text(0.5, 1.0, 'TV Vs Sales OBSERVED OUTPUT')

# %%
plt.scatter(x_test['radio'],y_test)
plt.plot(x_test['radio'],y_predictions,color='red',label="regression line")
plt.legend()
plt.xlabel('radio')
plt.ylabel('sales')
plt.title('radio Vs Sales OBSERVED OUTPUT')
# Out:
# Text(0.5, 1.0, 'radio Vs Sales OBSERVED OUTPUT')

# %%
plt.scatter(x_test['newspaper'],y_test)
plt.plot(x_test['newspaper'],y_predictions,color='red',label="regression line")
plt.legend()
plt.xlabel('newspaper')
plt.ylabel('sales')
plt.title('newpaper Vs Sales OBSERVED OUTPUT')
# Out:
# Text(0.5, 1.0, 'newpaper Vs Sales OBSERVED OUTPUT')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

MAE = mean_absolute_error(y_test,y_predictions)
MSE = mean_squared_error(y_test,y_predictions)
RMSE = np.sqrt(MSE)
print(f"Mean Absoulte Error = {MAE}")
print(f"Mean Sqaured Error = {MSE}")
print(f"Root Mean Squared Error ={RMSE}")
# Out:
# Mean Absoulte Error = 1.6795024935822132
# Mean Sqaured Error = 5.4312755260781795
# Root Mean Squared Error =2.330509713791852
